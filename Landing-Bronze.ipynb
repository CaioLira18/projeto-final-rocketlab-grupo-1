# %% [markdown]
# Configurando ambiente de trabalho

# %%
# %sql
create volume if not exists landing;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
create catalog if not exists stack_overgol;
use catalog stack_overgol;
create schema if not exists bronze;
create schema if not exists silver;
create schema if not exists gold;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# Transformando arquivos csv em tabelas delta no schema bronze

# %%
from pyspark.sql.functions import input_file_name
import os

base_path = "/Volumes/stack_overgol/default/landing"

files = [f.path for f in dbutils.fs.ls(base_path) if f.path.endswith(".csv")]

print("Tabelas criadas na camada Bronze: ")
for file in files:
    table_name = file.split("/")[-1].replace(".csv", "")
    
    df = (
        spark.read
        .option("header", True)
        .option("inferSchema", True)
        .option("sep", ",")
        .csv(file)
    )
    
    df.write.format("delta") \
        .mode("overwrite") \
        .saveAsTable(f"bronze.{table_name}")
    
    print(table_name)
# Out:
# Tabelas criadas na camada Bronze:
# avaliacoes
# catalogo_produtos
# clickstream
# clientes
# pedidos
# suporte_tickets
